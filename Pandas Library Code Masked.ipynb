# %% [markdown]
# #### Mount the notebook to your Google Drive folder.

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# #### Opening a .csv datafile and load the data

# %%
import pandas as pd
QA = pd.read_csv('/drive/My Drive/Teaching/2025 Spring/INFO 617/Lecture 2 Jan 27/INFO 617_Mental Health_QA.csv', encoding='latin-1')
print(QA.head(5))
# Out:
#    Unnamed: 0        QID                                   Question_English  \
# 0           0  100788023  Watching the elderly matchmaking program was v...
# 1           1  100788009  Falling in love with someone else and breaking...
# 2           2  100788013  I have been suffering from insomnia for half a...
# 3           3  100788013  I have been suffering from insomnia for half a...
# 4           4  100788013  I have been suffering from insomnia for half a...
#
#     author_ID                                     Answer_English  \
# 0  1004398689  Hello. Let's start by talking about young peop...
# 1  1006712632  Hello! Sending you a virtual hug first. Thumbs...
# 2  1000598896  Hello! ? I saw the issue you raised about inso...
# 3  1000598896  Hello! ? I saw the issue you raised about inso...
# 4  1006273111  Hi, I just want to hug you. I can feel the kin...
#
#    Usefulness_vote  Comment_count  Received_Bonus_Yes_No
# 0                2              0                      0
# 1                2              0                      0
# 2                8              2                      1
# 3                8              2                      0
# 4                6              0                      0

# %% [markdown]
# * ```encoding='latin-1'``` specifies the character encoding of the file, which is necessary to properly read the characters in the file. ```'latin-1'``` is a common encoding for text files. Some other commonly-used encoding methods include ```utf-8```, ```ASCII```, etc.

# %% [markdown]
# #### Explore the QA dataset with ```pandas``` methods
# * ```pandas``` is an open source data analysis and manipulation tool.
# * ```pandas``` built-in functions allow the user to load, clean, explore, and manipulate data.
# * ```pandas.DataFrame``` is a two-dimensional data structure that is similar to SQL tables.
# * Each column in a ```pandas.DataFrame``` is a ```pandas.Series```, which is a one-dimensional array.

# %%
# Let's get an overview of the dataset (dataframe) by obtaining the descriptive statistics of numerical columns.
QA.describe()
# Out:
#          Unnamed: 0           QID     author_ID  Usefulness_vote  \
# count  86397.000000  8.639700e+04  8.639700e+04     86397.000000
# mean   43198.000000  1.008195e+08  9.783670e+08         3.696066
# std    24940.809941  1.494921e+04  1.661463e+08         2.642346
# min        0.000000  1.007880e+08  3.620000e+02         0.000000
# 25%    21599.000000  1.008065e+08  1.006217e+09         2.000000
# 50%    43198.000000  1.008258e+08  1.008035e+09         3.000000
# 75%    64797.000000  1.008321e+08  1.009097e+09         5.000000
# max    86396.000000  1.008396e+08  1.011734e+09        31.000000
#
#        Comment_count  Received_Bonus_Yes_No
# count   86397.000000           86397.000000
# mean        0.188108               0.226779
# std         0.800155               0.431439
# min         0.000000               0.000000
# 25%         0.000000               0.000000
# 50%         0.000000               0.000000
# 75%         0.000000               0.000000
# max        35.000000               4.000000

# %%
# Let's get rid of the first column

# An alternative approach to drop the first column QA = QA.iloc[:, 1:]

# %%
# We can also obtain information of data type and data completeness for each column.
QA.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-edfc0bb9b3f7> in <cell line: 0>()
#       1 # We can also obtain information of data type and data completeness for each column.
# ----> 2 QA.info()
#
# NameError: name 'QA' is not defined

# %%
# Check the first 5 rows in the dataset.
QA.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fb29d081dde5> in <cell line: 0>()
#       1 # Check the first 5 rows in the dataset.
# ----> 2 QA.head(5)
#
# NameError: name 'QA' is not defined

# %%
# Print the last 5 rows in the dataset.
QA.tail(5)
# Out:
#              QID                                   Question_English  \
# 86392  100794310  A 22-year-old girl, no one is here to accompan...
# 86393  100794330  Always unable to stop recalling the past, to t...
# 86394  100794330  Always unable to stop recalling the past, to t...
# 86395  100794348  What to do if I have feelings for my sister-in...
# 86396  100794327  I have been diagnosed with severe depression a...
#
#         author_ID                                     Answer_English  \
# 86392  1006887364  Hello, OP. Throughout the entire post, I notic...
# 86393  1005261485  Hello, I hope my response can bring you some h...
# 86394  1004962530  Reading your question inadvertently reminded m...
# 86395  1000648295  Hello, how do you understand two people becomi...
# 86396  1006643830  Hello! I'm from the community of Whale Social ...
#
#        Usefulness_vote  Comment_count  Received_Bonus_Yes_No
# 86392                5              0                      0
# 86393                7              0                      0
# 86394                3              0                      0
# 86395                2              0                      0
# 86396                2              0                      0

# %%
# What are the columns in this dataset?

# QA.keys() also returns all columns in the data frame.
# Out:
# Index(['QID', 'Question_English', 'author_ID', 'Answer_English',
#        'Usefulness_vote', 'Comment_count', 'Received_Bonus_Yes_No'],
#       dtype='object')

# %% [markdown]
# * The "Unnamed: 0" column usually appears in pandas DataFrames when the CSV file you're reading has an index (row labels) but doesn't have a dedicated column header for it.

# %% [markdown]
# #### Access rows and columns

# %%
# Select a specific column in the dataset.
# Out:
# 0        100788023
# 1        100788009
# 2        100788013
# 3        100788013
# 4        100788013
#            ...
# 86392    100794310
# 86393    100794330
# 86394    100794330
# 86395    100794348
# 86396    100794327
# Name: QID, Length: 86397, dtype: int64

# %%
# Select two/multiple columns from the dataset.
# Out:
#              QID                                   Question_English
# 0      100788023  Watching the elderly matchmaking program was v...
# 1      100788009  Falling in love with someone else and breaking...
# 2      100788013  I have been suffering from insomnia for half a...
# 3      100788013  I have been suffering from insomnia for half a...
# 4      100788013  I have been suffering from insomnia for half a...
# ...          ...                                                ...
# 86392  100794310  A 22-year-old girl, no one is here to accompan...
# 86393  100794330  Always unable to stop recalling the past, to t...
# 86394  100794330  Always unable to stop recalling the past, to t...
# 86395  100794348  What to do if I have feelings for my sister-in...
# 86396  100794327  I have been diagnosed with severe depression a...
#
# [86397 rows x 2 columns]

# %%
# Select column(s) using indexing.
# Select the first column
QA.iloc[:,0]
# iloc stands for "integer location". This method is used to access and
# manipulate data in the DataFrame based on their integer location, i.e.,
# indices of their row and column %% Select multiple columns
# Out:
# 0        100788023
# 1        100788009
# 2        100788013
# 3        100788013
# 4        100788013
#            ...
# 86392    100794310
# 86393    100794330
# 86394    100794330
# 86395    100794348
# 86396    100794327
# Name: QID, Length: 86397, dtype: int64

# %%
# Select multiple columns using .iloc (integer location)
# Out:
#                                         Question_English   author_ID  \
# 0      Watching the elderly matchmaking program was v...  1004398689
# 1      Falling in love with someone else and breaking...  1006712632
# 2      I have been suffering from insomnia for half a...  1000598896
# 3      I have been suffering from insomnia for half a...  1000598896
# 4      I have been suffering from insomnia for half a...  1006273111
# ...                                                  ...         ...
# 86392  A 22-year-old girl, no one is here to accompan...  1006887364
# 86393  Always unable to stop recalling the past, to t...  1005261485
# 86394  Always unable to stop recalling the past, to t...  1004962530
# 86395  What to do if I have feelings for my sister-in...  1000648295
# 86396  I have been diagnosed with severe depression a...  1006643830
#
#                                           Answer_English
# 0      Hello. Let's start by talking about young peop...
# 1      Hello! Sending you a virtual hug first. Thumbs...
# 2      Hello! ? I saw the issue you raised about inso...
# 3      Hello! ? I saw the issue you raised about inso...
# 4      Hi, I just want to hug you. I can feel the kin...
# ...                                                  ...
# 86392  Hello, OP. Throughout the entire post, I notic...
# 86393  Hello, I hope my response can bring you some h...
# 86394  Reading your question inadvertently reminded m...
# 86395  Hello, how do you understand two people becomi...
# 86396  Hello! I'm from the community of Whale Social ...
#
# [86397 rows x 3 columns]

# %%
# Select multiple columns that are not adjacent using .iloc
# Out:
#              QID                                   Question_English  \
# 0      100788023  Watching the elderly matchmaking program was v...
# 1      100788009  Falling in love with someone else and breaking...
# 2      100788013  I have been suffering from insomnia for half a...
# 3      100788013  I have been suffering from insomnia for half a...
# 4      100788013  I have been suffering from insomnia for half a...
# ...          ...                                                ...
# 86392  100794310  A 22-year-old girl, no one is here to accompan...
# 86393  100794330  Always unable to stop recalling the past, to t...
# 86394  100794330  Always unable to stop recalling the past, to t...
# 86395  100794348  What to do if I have feelings for my sister-in...
# 86396  100794327  I have been diagnosed with severe depression a...
#
#                                           Answer_English  Comment_count
# 0      Hello. Let's start by talking about young peop...              0
# 1      Hello! Sending you a virtual hug first. Thumbs...              0
# 2      Hello! ? I saw the issue you raised about inso...              2
# 3      Hello! ? I saw the issue you raised about inso...              2
# 4      Hi, I just want to hug you. I can feel the kin...              0
# ...                                                  ...            ...
# 86392  Hello, OP. Throughout the entire post, I notic...              0
# 86393  Hello, I hope my response can bring you some h...              0
# 86394  Reading your question inadvertently reminded m...              0
# 86395  Hello, how do you understand two people becomi...              0
# 86396  Hello! I'm from the community of Whale Social ...              0
#
# [86397 rows x 4 columns]

# %%
# Select first 10 rows in the dataset

# The following two commands return the same results
# QA.iloc[:10,]
# QA.iloc[:10,:]
# Out:
#          QID                                   Question_English   author_ID  \
# 0  100788023  Watching the elderly matchmaking program was v...  1004398689
# 1  100788009  Falling in love with someone else and breaking...  1006712632
# 2  100788013  I have been suffering from insomnia for half a...  1000598896
# 3  100788013  I have been suffering from insomnia for half a...  1000598896
# 4  100788013  I have been suffering from insomnia for half a...  1006273111
# 5  100788013  I have been suffering from insomnia for half a...     9100417
# 6  100788013  I have been suffering from insomnia for half a...  1007632006
# 7  100788013  I have been suffering from insomnia for half a...  1007632006
# 8  100788013  I have been suffering from insomnia for half a...  1006771844
# 9  100788013  I have been suffering from insomnia for half a...  1005359282
#
#                                       Answer_English  Usefulness_vote  \
# 0  Hello. Let's start by talking about young peop...                2
# 1  Hello! Sending you a virtual hug first. Thumbs...                2
# 2  Hello! ? I saw the issue you raised about inso...                8
# 3  Hello! ? I saw the issue you raised about inso...                8
# 4  Hi, I just want to hug you. I can feel the kin...                6
# 5  Hello, OP: It sounds like you are really suffe...                6
# 6  Hello! I?ve been suffering from insomnia for h...                5
# 7  Hello! I?ve been suffering from insomnia for h...                5
# 8  Hello, you mentioned that you have been suffer...                2
# 9  Hello. I feel that insomnia is still quite com...                2
#
#    Comment_count  Received_Bonus_Yes_No
# 0              0                      0
# 1              0                      0
# 2              2                      1
# 3              2                      0
# 4              0                      0
# 5              0                      0
# 6              0                      1
# 7              0                      0
# 8              0                      0
# 9              1                      0

# %% [markdown]
# * ```QA.iloc[:10]``` selects the first 10 rows of the DataFrame QA. By default, when only the row indices are specified, all columns are included.
# * ```QA.iloc[:10,]``` is functionally identical to the first method. The comma indicates that both row and column indices could be specified, but since only the row slice :10 is provided, it defaults to including all columns.
# * ```QA.iloc[:10, :]``` specifies the first 10 rows, and ```:``` specifies all columns. This method explicitly states that all columns are to be included, but the result is the same as the previous two methods.

# %%
# Select the first three columns in the last ten rows
# Out:
#              QID                                   Question_English  \
# 86387  100794213  Too concerned about others' opinions and feeli...
# 86388  100794213  Too concerned about others' opinions and feeli...
# 86389  100794239  I really dislike my father. I feel like he's a...
# 86390  100794268  Both of us are married. If we start over, can ...
# 86391  100794326  When discussing important matters with myself,...
# 86392  100794310  A 22-year-old girl, no one is here to accompan...
# 86393  100794330  Always unable to stop recalling the past, to t...
# 86394  100794330  Always unable to stop recalling the past, to t...
# 86395  100794348  What to do if I have feelings for my sister-in...
# 86396  100794327  I have been diagnosed with severe depression a...
#
#         author_ID
# 86387  1008456236
# 86388  1008894622
# 86389  1008780429
# 86390  1006643834
# 86391  1006643830
# 86392  1006887364
# 86393  1005261485
# 86394  1004962530
# 86395  1000648295
# 86396  1006643830

# %% [markdown]
# * ```-10:``` This part selects the last 10 rows of the DataFrame. The negative sign - indicates counting from the end. So -10 means starting 10 rows from the bottom. The colon : means "up to the end".
# * ```:3``` This part selects the first 3 columns of the DataFrame. The colon : means "from the beginning" and 3 refers to the column index up to (but not including) 3. Since Python indexing starts at 0, this means columns 0, 1, and 2.

# %% [markdown]
# #### Data Manipulation: Maximum and minimum values

# %%
# How many observations (rows) are there in the dataset?
print("There are %d observations in the dataset." %QA.shape[0])
# Out:
# There are 86397 observations in the dataset.

# %%
# Can you create a list that contains all QIDs?

print(QIDs)
# Out:
# [100788023, 100788009, 100788013, 100788013, 100788013, 100788013, 100788013, 100788013, 100788013, 100788013, 100788013, 100788013, 100788017, 100788017, 100788017, 100788251, 100788368, 100788373, 100788399, 100788517, 100788566, 100788506, 100788506, 100788506, 100788646, 100788646, 100788646, 100788644, 100788644, 100788644, 100788644, 100788644, 100788644, 100788644, 100788644, 100788644, 100788644, 100788715, 100788715, 100788715, 100788715, 100788715, 100788715, 100788715, 100788765, 100788765, 100788914, 100788914, 100788914, 100788914, 100788914, 100788086, 100788267, 100788365, 100788571, 100788699, 100788867, 100788866, 100788866, 100788866, 100788866, 100788866, 100788866, 100788866, 100788866, 100788866, 100788866, 100788990, 100788990, 100788990, 100788990, 100788990, 100788990, 100789300, 100789300, 100789221, 100789221, 100789221, 100789221, 100789221, 100789221, 100789221, 100789221, 100789358, 100789483, 100789483, 100789483, 100789589, 100789589, 100789589, 100789589, 100789706, 100789891, 100789891, 100789891, 100789891, 100789891, 100790193, 100789628, 100789628, 100789628, 100789628, 100789628, 100789628, 100789628, 100789628, 100789628, 100790425, 100790425, 100790425, 100790610, 100790598, 100790598, 100790840, 100790840, 100790840, 100790840, 100790840, 100790840, 100790840, 100790984, 100791056, 100788198, 100788455, 100788455, 100788455, 100788455, 100788294, 100788556, 100788556, 100788751, 100788751, 100788862, 100788862, 100788862, 100788862, 100788885, 100788885, 100788885, 100788885, 100788885, 100788885, 100788885, 100788944, 100789087, 100789087, 100789087, 100789087, 100789087, 100789087, 100789087, 100789087, 100789087, 100789352, 100789586, 100789586, 100789586, 100789565, 100789565, 100789565, 100789595, 100789595, 100789595, 100789595, 100789957, 100789957, 100789957, 100789990, 100789743, 100789743, 100789743, 100790195, 100790195, 100790229, 100790393, 100790552, 100790552, 100790851, 100790851, 100790851, 100790851, 100790850, 100790912, 100791011, 100791011, 100791011, 100791011, 100791011, 100791011, 100791011, 100791011, 100791215, 100791215, 100791264, 100791441, 100791461, 100791461, 100791461, 100791727, 100791988, 100791988, 100791988, 100791942, 100792312, 100792403, 100792403, 100792449, 100792449, 100792544, 100792544, 100792587, 100792587, 100792587, 100792587, 100792587, 100792587, 100792587, 100792587, 100792587, 100792587, 100792924, 100792924, 100792927, 100793073, 100793073, 100793073, 100793073, 100793073, 100793309, 100793309, 100793309, 100793309, 100793309, 100793309, 100793309, 100793309, 100793561, 100793616, 100793915, 100793817, 100793817, 100793817, 100793960, 100794421, 100794421, 100794421, 100794421, 100794421, 100794421, 100794467, 100794467, 100794467, 100794467, 100794480, 100794480, 100794652, 100794880, 100794880, 100794880, 100795163, 100795262, 100795262, 100795376, 100795717, 100795717, 100795717, 100795717, 100795717, 100795717, 100795920, 100796627, 100796627, 100797100, 100797100, 100797298, 100797298, 100797298, 100797298, 100797298, 100797298, 100797298, 100797298, 100797298, 100797577, 100797577, 100797395, 100797395, 100797395, 100797395, 100797395, 100797395, 100797708, 100797708, 100797708, 100797803, 100797886, 100797617, 100797617, 100797617, 100797617, 100797617, 100797617, 100797617, 100798493, 100798493, 100798493, 100798763, 100798763, 100798763, 100798763, 100798763, 100798763, 100798442, 100799133, 100799133, 100799133, 100799133, 100799133, 100799133, 100799133, 100799133, 100799133, 100799133, 100799516, 100799516, 100799455, 100799516, 100799564, 100799735, 100799735, 100799735, 100799731, 100799872, 100799872, 100799872, 100799872, 100799872, 100799872, 100799872, 100799872, 100799872, 100800062, 100800062, 100799753, 100799753, 100799753, 100788154, 100788154, 100788154, 100788562, 100788743, 100788743, 100788743, 100789164, 100789164, 100789604, 100789414, 100789705, 100789847, 100789847, 100789847, 100790070, 100790070, 100790 ...

# %% [markdown]
# * It seems like a question (QID) may receive responses from multiple authors. Can you create a dictionary that keeps the number of responses each question received?

# %%
# Can you create a dictionary that keeps the number of responses each question received?
QA_Num_of_Responses = {}


print(QA_Num_of_Responses)
# Out:
# {100794369: 8, 100794370: 2, 100794371: 3, 100794376: 3, 100794377: 1, 100794378: 2, 100794380: 2, 100794381: 2, 100794382: 4, 100794383: 2, 100794384: 2, 100794385: 3, 100794387: 3, 100794388: 1, 100794389: 1, 100794390: 1, 100794391: 1, 100794392: 1, 100794393: 1, 100794394: 1, 100794395: 1, 100794396: 1, 100794397: 1, 100794398: 1, 100794399: 1, 100794400: 2, 100794401: 1, 100794402: 1, 100794403: 1, 100794404: 1, 100794405: 2, 100794406: 1, 100794407: 1, 100794408: 1, 100794409: 1, 100794410: 3, 100794411: 1, 100794412: 1, 100794413: 2, 100794414: 1, 100794415: 2, 100794416: 4, 100794417: 4, 100794418: 3, 100794419: 2, 100794420: 1, 100794421: 6, 100794422: 2, 100794423: 13, 100794424: 1, 100794426: 1, 100794427: 3, 100794428: 1, 100794429: 1, 100794430: 1, 100794432: 2, 100794433: 7, 100794436: 1, 100794437: 1, 100794438: 14, 100794440: 4, 100794441: 1, 100794442: 5, 100794444: 2, 100794445: 4, 100794448: 3, 100794449: 1, 100794453: 2, 100794454: 3, 100794455: 1, 100794456: 1, 100794457: 2, 100794458: 2, 100794459: 2, 100794460: 5, 100794462: 3, 100794463: 2, 100794464: 9, 100794467: 4, 100794468: 3, 100794472: 3, 100794477: 7, 100794478: 2, 100794479: 2, 100794480: 2, 100794481: 4, 100794482: 8, 100794484: 3, 100794485: 1, 100794486: 1, 100794488: 1, 100794489: 4, 100794492: 2, 100794494: 4, 100794495: 1, 100794496: 2, 100794498: 5, 100794500: 4, 100794501: 7, 100794502: 3, 100794503: 1, 100794505: 3, 100794506: 2, 100794507: 7, 100794508: 2, 100794509: 3, 100794511: 2, 100794512: 1, 100794513: 4, 100794514: 6, 100794517: 10, 100794518: 5, 100794519: 2, 100794520: 1, 100794521: 1, 100794522: 1, 100794523: 1, 100794524: 1, 100794525: 1, 100794526: 1, 100794527: 1, 100794528: 1, 100794529: 8, 100794530: 1, 100794531: 1, 100794532: 1, 100794533: 1, 100794534: 6, 100794535: 2, 100794536: 1, 100794537: 1, 100794538: 1, 100794539: 1, 100794540: 1, 100794541: 1, 100794542: 1, 100794543: 1, 100794544: 1, 100794545: 2, 100794546: 1, 100794547: 1, 100794548: 1, 100794549: 3, 100794550: 1, 100794551: 1, 100794552: 3, 100794553: 6, 100794554: 1, 100794555: 1, 100794557: 3, 100794558: 6, 100794559: 1, 100794560: 3, 100794561: 2, 100794562: 2, 100794563: 9, 100794564: 10, 100794565: 1, 100794566: 1, 100794567: 8, 100794569: 1, 100794570: 10, 100794571: 1, 100794574: 1, 100794575: 2, 100794576: 6, 100794577: 2, 100794579: 1, 100794580: 1, 100794581: 5, 100794583: 1, 100794584: 12, 100794585: 3, 100794588: 2, 100794589: 4, 100794594: 1, 100794596: 1, 100794597: 1, 100794600: 2, 100794601: 7, 100794602: 1, 100794603: 8, 100794604: 1, 100794606: 7, 100794608: 6, 100794609: 2, 100794612: 1, 100794613: 1, 100794614: 2, 100794616: 3, 100794621: 1, 100794623: 1, 100794624: 8, 100794625: 1, 100794626: 1, 100794627: 6, 100794628: 8, 100794629: 1, 100794632: 1, 100794636: 1, 100794637: 2, 100794639: 2, 100794640: 1, 100794641: 2, 100794642: 1, 100794643: 8, 100794644: 1, 100794645: 3, 100794646: 1, 100794647: 1, 100794648: 1, 100794649: 1, 100794650: 1, 100794651: 1, 100794652: 1, 100794653: 1, 100794654: 1, 100794655: 1, 100794656: 2, 100794657: 1, 100794658: 2, 100794659: 3, 100794660: 1, 100794661: 1, 100794662: 1, 100794663: 3, 100794664: 1, 100794665: 1, 100794666: 1, 100794667: 1, 100794668: 1, 100794669: 1, 100794671: 1, 100794673: 1, 100794674: 1, 100794675: 3, 100794676: 1, 100794677: 2, 100794678: 1, 100794679: 2, 100794680: 1, 100794681: 1, 100794682: 1, 100794683: 1, 100794684: 1, 100794685: 2, 100794686: 1, 100794687: 2, 100794688: 1, 100794689: 1, 100794690: 1, 100794691: 1, 100794692: 2, 100794693: 2, 100794694: 1, 100794695: 1, 100794696: 1, 100794697: 2, 100794698: 1, 100794699: 1, 100794700: 1, 100794701: 1, 100794702: 1, 100794703: 1, 100794704: 1, 100794705: 1, 100794706: 1, 100794707: 1, 100794708: 1, 100794709: 1, 100794710: 1, 100794711: 2, 100794712: 1, 100794714: 1, 100794715: 3, 100794716: 1, 100794717: 2, 100794718: 2, 100794719: 3, 100794720: 2, 100794721: 1, 100794722: 1, 100794723: 5, 100794724: 1, 100794727: 3, 100 ...

# %%
# Which question received the most responses, and how many responses did it receive?
[qid for qid in set(QIDs) if QA_Num_of_Responses[qid] == max(QA_Num_of_Responses.values())]
# Out:
# [100828082]

# %%
# Is there another way to identify this question ID?
max_QID = max(QA_Num_of_Responses, key=QA_Num_of_Responses.get)
print(max_QID)
# Out:
# 100828082

# %% [markdown]
# * ```key=QA_Num_of_Responses.get```  is the crucial part in the command. It specifies a custom function ```QA_Num_of_Responses.get``` to be used by ```max()``` to determine the maximum. The ```.get``` method of a dictionary returns the value associated with a given key. In this case, for each ```QID (key)``` in the dictionary, ```QA_Num_of_Responses.get``` will return the number of responses (value).

# %% [markdown]
# * However, the ```max()``` function only returns the **first** key value it encounters that is associated with the maximum value.
#
# * This limitation is manifested  clearly in the following example where we seek to find questions that received the least amount of responses.

# %%
# The least amount of response to keep a question in our dataset
print(min(QA_Num_of_Responses.values()))
# Out:
# 1

# %%
# Which question received the most responses, and how many responses did it receive?
[qid for qid in set(QIDs) if QA_Num_of_Responses[qid] == min(QA_Num_of_Responses.values())]
# Out:
# [100794377,
#  100794388,
#  100794389,
#  100794390,
#  100794391,
#  100794392,
#  100794393,
#  100794394,
#  100794395,
#  100794396,
#  100794397,
#  100794398,
#  100794399,
#  100794401,
#  100794402,
#  100794403,
#  100794404,
#  100794406,
#  100794407,
#  100794408,
#  100794409,
#  100794411,
#  100794412,
#  100794414,
#  100794420,
#  100794424,
#  100794426,
#  100794428,
#  100794429,
#  100794430,
#  100794436,
#  100794437,
#  100794441,
#  100794449,
#  100794455,
#  100794456,
#  100794485,
#  100794486,
#  100794488,
#  100794495,
#  100794503,
#  100794512,
#  100794520,
#  100794521,
#  100794522,
#  100794523,
#  100794524,
#  100794525,
#  100794526,
#  100794527,
#  100794528,
#  100794530,
#  100794531,
#  100794532,
#  100794533,
#  100794536,
#  100794537,
#  100794538,
#  100794539,
#  100794540,
#  100794541,
#  100794542,
#  100794543,
#  100794544,
#  100794546,
#  100794547,
#  100794548,
#  100794550,
#  100794551,
#  100794554,
#  100794555,
#  100794559,
#  100794565,
#  100794566,
#  100794569,
#  100794571,
#  100794574,
#  100794579,
#  100794580,
#  100794583,
#  100794594,
#  100794596,
#  100794597,
#  100794602,
#  100794604,
#  100794612,
#  100794613,
#  100794621,
#  100794623,
#  100794625,
#  100794626,
#  100794629,
#  100794632,
#  100794636,
#  100794640,
#  100794642,
#  100794644,
#  100794646,
#  100794647,
#  100794648,
#  100794649,
#  100794650,
#  100794651,
#  100794652,
#  100794653,
#  100794654,
#  100794655,
#  100794657,
#  100794660,
#  100794661,
#  100794662,
#  100794664,
#  100794665,
#  100794666,
#  100794667,
#  100794668,
#  100794669,
#  100794671,
#  100794673,
#  100794674,
#  100794676,
#  100794678,
#  100794680,
#  100794681,
#  100794682,
#  100794683,
#  100794684,
#  100794686,
#  100794688,
#  100794689,
#  100794690,
#  100794691,
#  100794694,
#  100794695,
#  100794696,
#  100794698,
#  100794699,
#  100794700,
#  100794701,
#  100794702,
#  100794703,
#  100794704,
#  100794705,
#  100794706,
#  100794707,
#  100794708,
#  100794709,
#  100794710,
#  100794712,
#  100794714,
#  100794716,
#  100794721,
#  100794722,
#  100794724,
#  100794741,
#  100794743,
#  100794744,
#  100794746,
#  100794759,
#  100794760,
#  100794770,
#  100794774,
#  100794775,
#  100794786,
#  100794789,
#  100794803,
#  100794806,
#  100794807,
#  100794808,
#  100794809,
#  100794810,
#  100794814,
#  100794819,
#  100794822,
#  100794823,
#  100794828,
#  100794829,
#  100794836,
#  100794837,
#  100794839,
#  100794840,
#  100794841,
#  100794842,
#  100794843,
#  100794844,
#  100794847,
#  100794848,
#  100794849,
#  100794850,
#  100794852,
#  100794853,
#  100794854,
#  100794855,
#  100794857,
#  100794858,
#  100794859,
#  100794860,
#  100794861,
#  100794862,
#  100794866,
#  100794889,
#  100794890,
#  100794892,
#  100794894,
#  100794896,
#  100794898,
#  100794899,
#  100794901,
#  100794902,
#  100794903,
#  100794905,
#  100794906,
#  100794908,
#  100794909,
#  100794911,
#  100794912,
#  100794914,
#  100794915,
#  100794917,
#  100794920,
#  100794936,
#  100794941,
#  100794945,
#  100794950,
#  100794953,
#  100794956,
#  100794958,
#  100794959,
#  100794962,
#  100794963,
#  100794964,
#  100794980,
#  100794996,
#  100794999,
#  100795003,
#  100795012,
#  100795015,
#  100795016,
#  100795017,
#  100795019,
#  100795020,
#  100795021,
#  100795022,
#  100795023,
#  100795024,
#  100795025,
#  100795026,
#  100795027,
#  100795028,
#  100795029,
#  100795032,
#  100795033,
#  100795034,
#  100795035,
#  100795036,
#  100795038,
#  100795039,
#  100795040,
#  100795041,
#  100795046,
#  100795047,
#  100795049,
#  100795050,
#  100795051,
#  100795052,
#  100795053,
#  100795054,
#  100795055,
#  100795063,
#  100795065,
#  100795066,
#  100795069,
#  100795070,
#  100795072,
#  100795074,
#  100795075,
#  100795076,
#  100795077,
#  100795080,
#  100795081,
#  100795085,
#  100795086,
#  100795089,
#  100795092,
#  100795093,
#  100795094,
#  100795096,
#  100795108,
#  100795114,
#  100795118,
#  100795121,
#  100795122,
#  100795123,
#  100795126,
#  100795127,
#  100795129,
#  100795133,
#  100795135,
#  100795136,
#  100795140,
#  100795141,
#  100795142,
#  100795143,
#  100795144,
#  100795145,
#  100795146,
#  100795147,
#  100795148,
#  100795150,
#  100795151,
#  100795152,
#  100795153,
#  100795154,
#  100795155,
#  100795157,
#  100795158,
#  100795160,
#  100795162,
#  100795163,
#  100795165,
#  100795166,
#  100795167,
#  100795168,
#  100795170,
#  100795172,
#  100795175,
#  100795176,
#  100795184,
#  100795188,
#  100795189,
#  100795199,
#  100795223,
#  100795232,
#  100795241,
#  100795264,
#  100795266,
#  100795268,
#  100795270,
#  100795272,
#  100795278,
#  100795280,
#  100795282,
#  100795283,
#  100795284,
#  100795286,
#  100795290,
#  100795292,
#  100795296,
#  100795297,
#  100795299,
#  100795301,
#  100795303,
#  100795305,
#  100795307,
#  100795309,
#  100795310,
#  100795311,
#  100795312,
#  100795313,
#  100795315,
#  100795318,
#  100795320,
#  100795325,
#  100795328,
#  100795332,
#  100795334,
#  100795339,
#  100795353,
#  100795363,
#  100795369,
#  100795373,
#  100795375,
#  100795376,
#  100795377,
#  100795378,
#  100795379,
#  100795380,
#  100795381,
#  100795382,
#  100795383,
#  100795384,
#  100795385,
#  100795388,
#  100795389,
#  100795390,
#  100795391,
#  100795392,
#  100795393,
#  100795394,
#  100795395,
#  100795396,
#  100795399,
#  100795400,
#  100795402,
#  100795403,
#  100795406,
#  100795407,
#  100795408,
#  100795409,
#  100795411,
#  100795412,
#  100795413,
#  100795414,
#  100795418,
#  100795423,
#  100795424,
#  100795425,
#  100795426,
#  100795427,
#  100795430,
#  100795432,
#  100795434,
#  100795435,
#  100795442,
#  100795446,
#  100795448,
#  100795450,
#  100795453,
#  100795454,
#  100795459,
#  100795461,
#  100795471,
#  100795474,
#  100795475,
#  100795476,
#  100795477,
#  100795479,
#  100795480,
#  100795481,
#  100795483,
#  100795484,
#  100795485,
#  100795487,
#  100795491,
#  100795492,
#  100795493,
#  100795495,
#  100795496,
#  100795497,
#  100795498,
#  100795500,
#  100795501,
#  100795507,
#  100795508,
#  100795510,
#  100795514,
#  100795515,
#  100795521,
#  100795525,
#  100795527,
#  100795529,
#  100795530,
#  100795531,
#  100795533,
#  100795535,
#  100795536,
#  100795538,
#  100795543,
#  100795547,
#  100795549,
#  100795552,
#  100795553,
#  100795554,
#  100795556,
#  100795574,
#  100795577,
#  100795584,
#  100795591,
#  100795593,
#  100795597,
#  100795599,
#  100795601,
#  100795605,
#  100795607,
#  100795608,
#  100795609,
#  100795613,
#  100795614,
#  100795615,
#  100795616,
#  100795617,
#  100795618,
#  100795619,
#  100795620,
#  100795621,
#  100795622,
#  100795625,
#  100795626,
#  100795627,
#  100795628,
#  100795629,
#  100795632,
#  100795642,
#  100795643,
#  100795647,
#  100795653,
#  100795655,
#  100795656,
#  100795658,
#  100795659,
#  100795662,
#  100795663,
#  100795670,
#  100795671,
#  100795672,
#  100795673,
#  100795676,
#  100795677,
#  100795679,
#  100795682,
#  100795683,
#  100795685,
#  100795687,
#  100795705,
#  100795709,
#  100795711,
#  100795712,
#  100795723,
#  100795724,
#  100795725,
#  100795727,
#  100795731,
#  100795733,
#  100795735,
#  100795742,
#  100795746,
#  100795747,
#  100795748,
#  100795750,
#  100795752,
#  100795753,
#  100795754,
#  100795755,
#  100795757,
#  100795758,
#  100795760,
#  100795761,
#  100795762,
#  100795763,
#  100795764,
#  100795767,
#  100795769,
#  100795770,
#  100795774,
#  100795775,
#  100795778,
#  100795779,
#  100795784,
#  100795785,
#  100795791,
#  100795794,
#  100795795,
#  100795796,
#  100795798,
#  100795799,
#  100795801,
#  100795803,
#  100795804,
#  100795805,
#  100795807,
#  100795808,
#  100795809,
#  100795810,
#  100795819,
#  100795820,
#  100795821,
#  100795822,
#  100795825,
#  100795829,
#  100795830,
#  100795831,
#  100795832,
#  100795833,
#  100795840,
#  100795841,
#  100795842,
#  100795844,
#  100795846,
#  100795851,
#  100795852,
#  100795853,
#  100795855,
#  100795858,
#  100795860,
#  100795865,
#  100795872,
#  100795873,
#  100795879,
#  100795880,
#  100795881,
#  100795882,
#  100795885,
#  100795887,
#  100795888,
#  100795891,
#  100795893,
#  100795895,
#  100795896,
#  100795897,
#  100795898,
#  100795899,
#  100795900,
#  100795901,
#  100795902,
#  100795903,
#  100795904,
#  100795905,
#  100795906,
#  100795908,
#  100795909,
#  100795910,
#  100795911,
#  100795912,
#  100795913,
#  100795914,
#  100795915,
#  100795917,
#  100795918,
#  100795920,
#  100795921,
#  100795922,
#  100795923,
#  100795924,
#  100795925,
#  100795932,
#  100795935,
#  100795937,
#  100795949,
#  100795950,
#  100795967,
#  100795972,
#  100795975,
#  100795977,
#  100795978,
#  100795981,
#  100795982,
#  100795984,
#  100795985,
#  100795986,
#  100795987,
#  100795988,
#  100795989,
#  100795990,
#  100795991,
#  100795992,
#  100795993,
#  100795994,
#  100795995,
#  100795996,
#  100796000,
#  100796001,
#  100796003,
#  100796005,
#  100796007,
#  100796012,
#  100796014,
#  100796017,
#  100796020,
#  100796023,
#  100796024,
#  100796025,
#  100796026,
#  100796030,
#  100796031,
#  100796033,
#  100796034,
#  100796035,
#  100796040,
#  100796043,
#  100796044,
#  100796046,
#  100796048,
#  100796052,
#  100796054,
#  100796057,
#  100796059,
#  100796061,
#  100796063,
#  100796064,
#  100796067,
#  100796074,
#  100796075,
#  100796081,
#  100796084,
#  100796085,
#  100796086,
#  100796088,
#  100796091,
#  100796094,
#  100796103,
#  100796104,
#  100796105,
#  100796106,
#  100796107,
#  100796108,
#  100796109,
#  100796110,
#  100796111,
#  100796112,
#  100796113,
#  100796114,
#  100796115,
#  100796117,
#  100796118,
#  100796119,
#  100796120,
#  100796121,
#  100796122,
#  100796123,
#  100796124,
#  100796125,
#  100796128,
#  100796129,
#  100796130,
#  100796134,
#  100796135,
#  100796144,
#  100796148,
#  100796152,
#  100796161,
#  100796184,
#  100796188,
#  100796189,
#  100796192,
#  100796203,
#  100796219,
#  100796221,
#  100796222,
#  100796229,
#  100796231,
#  100796232,
#  100796234,
#  100796237,
#  100796239,
#  100796240,
#  100796242,
#  100796246,
#  100796251,
#  100796253,
#  100796255,
#  100796258,
#  100796259,
#  100796268,
#  100796269,
#  100796272,
#  100796273,
#  100796274,
#  100796275,
#  100796279,
#  100796282,
#  100796283,
#  100796284,
#  100796286,
#  100796291,
#  100796292,
#  100796293,
#  100796295,
#  100796296,
#  100796297,
#  100796298,
#  100796299,
#  100796301,
#  100796302,
#  100796303,
#  100796304,
#  100796306,
#  100796307,
#  100796308,
#  100796309,
#  100796310,
#  100796312,
#  100796316,
#  100796337,
#  100796341,
#  100796342,
#  100796343,
#  100796347,
#  100796352,
#  100796353,
#  100796355,
#  100796371,
#  100796372,
#  100796375,
#  100796376,
#  100796388,
#  100796389,
#  100796392,
#  100796393,
#  100796397,
#  100796398,
#  100796406,
#  100796408,
#  100796409,
#  100796410,
#  100796411,
#  100796412,
#  100796413,
#  100796416,
#  100796417,
#  100796418,
#  100796419,
#  100796421,
#  100796422,
#  100796423,
#  100796424,
#  100796425,
#  100796426,
#  100796428,
#  100796429,
#  100796430,
#  100796431,
#  100796435,
#  100796436,
#  100796437,
#  100796441,
#  100796443,
#  100796454,
#  100796455,
#  100796456,
#  100796459,
#  100796460,
#  100796466,
#  100796467,
#  100796494,
#  100796495,
#  100796496,
#  100796497,
#  100796498,
#  100796499,
#  100796500,
#  100796501,
#  100796502,
#  100796504,
#  100796505,
#  100796506,
#  100796507,
#  100796508,
#  100796509,
#  100796510,
#  100796511,
#  100796512,
#  100796514,
#  100796515,
#  100796516,
#  100796517,
#  100796518,
#  100796519,
#  100796520,
#  100796522,
#  100796526,
#  100796528,
#  100796529,
#  100796531,
#  100796535,
#  100796537,
#  100796538,
#  100796539,
#  100796549,
#  100796551,
#  100796553,
#  100796554,
#  100796555,
#  100796556,
#  100796557,
#  100796558,
#  100796563,
#  100796572,
#  100796573,
#  100796575,
#  100796576,
#  100796577,
#  100796578,
#  100796579,
#  100796580,
#  100796581,
#  100796582,
#  100796583,
#  100796584,
#  100796585,
#  100796586,
#  100796589,
#  100796590,
#  100796591,
#  100796592,
#  100796593,
#  100796594,
#  100796600,
#  100796601,
#  100796604,
#  100796607,
#  100796612,
#  100796615,
#  100796618,
#  100796619,
#  100796620,
#  100796630,
#  100796635,
#  100796636,
#  100796637,
#  100796639,
#  100796645,
#  100796647,
#  100796649,
#  100796659,
#  100796660,
#  100796661,
#  100796668,
#  100796675,
#  100796684,
#  100796685,
#  100796686,
#  100796688,
#  100796689,
#  100796690,
#  100796691,
#  100796692,
#  100796693,
#  100796694,
#  100796695,
#  100796696,
#  100796697,
#  100796698,
#  100796699,
#  100796700,
#  100796702,
#  100796703,
#  100796704,
#  100796705,
#  100796706,
#  100796708,
#  100796710,
#  100796711,
#  100796713,
#  100796714,
#  100796715,
#  100796716,
#  100796717,
#  100796718,
#  100796719,
#  100796720,
#  100796722,
#  100796724,
#  100796725,
#  100796727,
#  100796728,
#  100796731,
#  100796732,
#  100796738,
#  100796746,
#  100796750,
#  100796752,
#  100796753,
#  100796754,
#  100796755,
#  100796775,
#  100796776,
#  100796777,
#  100796778,
#  100796779,
#  100796780,
#  100796781,
#  100796782,
#  100796783,
#  100796784,
#  100796785,
#  100796786,
#  100796787,
#  100796788,
#  100796789,
#  100796790,
#  100796792,
#  100796795,
#  100796796,
#  100796798,
#  100796799,
#  100796800,
#  100796801,
#  100796804,
#  100796805,
#  100796817,
#  100796819,
#  100796821,
#  100796822,
#  100796832,
#  100796834,
#  100796836,
#  100796837,
#  100796843,
#  100796850,
#  100796851,
#  100796853,
#  100796857,
#  100796858,
#  100796859,
#  100796863,
#  100796869,
#  100796881,
#  100796882,
#  100796883,
#  100796884,
#  ...]

# %% [markdown]
# * It seems that many questions received the least amount of responses, which is one in our dataset.

# %% [markdown]
# * Only one question ID is returned by the built in ```min()``` function, though the execution is much faster.

# %%
# Is there another way to find out this question?
min_QID = min(QA_Num_of_Responses, key=QA_Num_of_Responses.get)
print(min_QID)
# Out:
# 100794377

# %% [markdown]
# #### Data Manipulation: Length of string data types

# %%
# Let's calculate the length of the first 50 answers.
# Out:
# 2116
# 1075
# 3716
# 3716
# 3481
# 1714
# 3986
# 3986
# 995
# 2091
# 367
# 556
# 1897
# 1897
# 1614
# 1560
# 4750
# 1060
# 2583
# 2081
# 1320
# 3978
# 2032
# 1608
# 2293
# 432
# 688
# 5300
# 3060
# 1554
# 3071
# 1607
# 1884
# 1517
# 1176
# 997
# 605
# 2668
# 2552
# 1531
# 4130
# 704
# 1292
# 645
# 564
# 1152
# 708
# 1164
# 1970
# 894

# %% [markdown]
# ##### The ```lambda``` function can be used to simplify the algorithm.

# %%
# The lambda function can be used to calculate the length of a string type element
QA['Answer_English'].iloc[:50].apply(lambda x: len(x))
# Out:
# 0     2116
# 1     1075
# 2     3716
# 3     3716
# 4     3481
# 5     1714
# 6     3986
# 7     3986
# 8      995
# 9     2091
# 10     367
# 11     556
# 12    1897
# 13    1897
# 14    1614
# 15    1560
# 16    4750
# 17    1060
# 18    2583
# 19    2081
# 20    1320
# 21    3978
# 22    2032
# 23    1608
# 24    2293
# 25     432
# 26     688
# 27    5300
# 28    3060
# 29    1554
# 30    3071
# 31    1607
# 32    1884
# 33    1517
# 34    1176
# 35     997
# 36     605
# 37    2668
# 38    2552
# 39    1531
# 40    4130
# 41     704
# 42    1292
# 43     645
# 44     564
# 45    1152
# 46     708
# 47    1164
# 48    1970
# 49     894
# Name: Answer_English, dtype: int64

# %% [markdown]
# * ```.apply(lambda x: len(x))``` is where the length calculation happens.
# ** ```.apply()``` is a method that applies a function to each element of a pandas Series (in this case, each of the first 50 answers).
# ** ```lambda x: len(x)``` is a lambda function, which is a small, anonymous function defined inline.

# %% [markdown]
# * Let's convert the existing column ```Received_Bonus_Yes_No``` to a new column. If the answer received a bonus (the original column takes a value 1), this new column would take a value "Yes", otherwise it takes the value "No." How to create this new column using the ```lambda``` function?

# %%
# Out:
#        Received_Bonus_Yes_No New_Column
# 0                          0         No
# 1                          0         No
# 2                          1        Yes
# 3                          0         No
# 4                          0         No
# ...                      ...        ...
# 86392                      0         No
# 86393                      0         No
# 86394                      0         No
# 86395                      0         No
# 86396                      0         No
#
# [86397 rows x 2 columns]

# %%
# Calculate the length of a string data object using the string method len().
# Out:
# 0        2116
# 1        1075
# 2        3716
# 3        3716
# 4        3481
#          ...
# 86392    1693
# 86393    7057
# 86394     825
# 86395     711
# 86396    1560
# Name: Answer_English, Length: 86397, dtype: int64

# %% [markdown]
# * ```.str``` is an accessor that allows you to apply string methods to a pandas Series (which is what ```QA['Answer_English']``` is). It basically says, "treat the elements in this Series as strings."
#
# * ```.lower()``` is the actual string method that converts all characters in each string to lowercase.

# %% [markdown]
# #### String methods
# * String methods make it easy to operate on each element of the pandas ```Series```.

# %%
# Make all answers in lower case.
# Out:
# 0        hello. let's start by talking about young peop...
# 1        hello! sending you a virtual hug first. thumbs...
# 2        hello! ? i saw the issue you raised about inso...
# 3        hello! ? i saw the issue you raised about inso...
# 4        hi, i just want to hug you. i can feel the kin...
#                                ...
# 86392    hello, op. throughout the entire post, i notic...
# 86393    hello, i hope my response can bring you some h...
# 86394    reading your question inadvertently reminded m...
# 86395    hello, how do you understand two people becomi...
# 86396    hello! i'm from the community of whale social ...
# Name: Answer_English, Length: 86397, dtype: object

# %%
# Remove spaces at the beginning and at the end of the string
QA['Answer_English'].str.strip()
# Out:
# 0        Hello. Let's start by talking about young peop...
# 1        Hello! Sending you a virtual hug first. Thumbs...
# 2        Hello! ? I saw the issue you raised about inso...
# 3        Hello! ? I saw the issue you raised about inso...
# 4        Hi, I just want to hug you. I can feel the kin...
#                                ...
# 86392    Hello, OP. Throughout the entire post, I notic...
# 86393    Hello, I hope my response can bring you some h...
# 86394    Reading your question inadvertently reminded m...
# 86395    Hello, how do you understand two people becomi...
# 86396    Hello! I'm from the community of Whale Social ...
# Name: Answer_English, Length: 86397, dtype: object

# %%
# Replace "Hello" with "Goodbye"
# Out:
# 0        Goodbye. Let's start by talking about young pe...
# 1        Goodbye! Sending you a virtual hug first. Thum...
# 2        Goodbye! ? I saw the issue you raised about in...
# 3        Goodbye! ? I saw the issue you raised about in...
# 4        Hi, I just want to hug you. I can feel the kin...
#                                ...
# 86392    Goodbye, OP. Throughout the entire post, I not...
# 86393    Goodbye, I hope my response can bring you some...
# 86394    Reading your question inadvertently reminded m...
# 86395    Goodbye, how do you understand two people beco...
# 86396    Goodbye! I'm from the community of Whale Socia...
# Name: Answer_English, Length: 86397, dtype: object

# %%
# Split each element in the column using the space as a delimiter
# Out:
# 0        [Hello., Let's, start, by, talking, about, you...
# 1        [Hello!, Sending, you, a, virtual, hug, first....
# 2        [Hello!, ?, I, saw, the, issue, you, raised, a...
# 3        [Hello!, ?, I, saw, the, issue, you, raised, a...
# 4        [Hi,, I, just, want, to, hug, you., I, can, fe...
#                                ...
# 86392    [Hello,, OP., Throughout, the, entire, post,, ...
# 86393    [Hello,, I, hope, my, response, can, bring, yo...
# 86394    [Reading, your, question, inadvertently, remin...
# 86395    [Hello,, how, do, you, understand, two, people...
# 86396    [Hello!, I'm, from, the, community, of, Whale,...
# Name: Answer_English, Length: 86397, dtype: object

# %% [markdown]
# * A Series of list is returned.

# %%
# To access the first element in each list

# You obtained the first word in each answer
# Out:
# 0         Hello.
# 1         Hello!
# 2         Hello!
# 3         Hello!
# 4            Hi,
#           ...
# 86392     Hello,
# 86393     Hello,
# 86394    Reading
# 86395     Hello,
# 86396     Hello!
# Name: Answer_English, Length: 86397, dtype: object

# %% [markdown]
# #### Indexing Methods

# %% [markdown]
# * Both ```.iloc``` and ```.loc``` are indexing methods built in the Python pandas library. The difference is ```.iloc``` uses integer-based indexing, similar to how to access elements in lists or arrays. Typically, you provide a row and column number to select specific elements.
#
# * On the other hand, ```.loc``` uses label-based indexing, meaning that it accepts row and column names as input.

# %%
# Let's get the element in the first row and first column, i.e., the first QID
# in the dataset.
print(QA.iloc[0,0])
# Out:
# 100788023

# %%
# To retrieve the same element, we can use the .loc function with modifications
# to the input.

# Here, '0' represents the name of the first row.
# Out:
# 100788023

# %%
# It is also possible to select multiple rows and columns using both indexing
# methods.
# Out:
#           QID                                   Question_English   author_ID
# 0   100788023  Watching the elderly matchmaking program was v...  1004398689
# 1   100788009  Falling in love with someone else and breaking...  1006712632
# 2   100788013  I have been suffering from insomnia for half a...  1000598896
# 3   100788013  I have been suffering from insomnia for half a...  1000598896
# 4   100788013  I have been suffering from insomnia for half a...  1006273111
# 5   100788013  I have been suffering from insomnia for half a...     9100417
# 6   100788013  I have been suffering from insomnia for half a...  1007632006
# 7   100788013  I have been suffering from insomnia for half a...  1007632006
# 8   100788013  I have been suffering from insomnia for half a...  1006771844
# 9   100788013  I have been suffering from insomnia for half a...  1005359282
# 10  100788013  I have been suffering from insomnia for half a...  1009083171

# %% [markdown]
# #### Loop through Python DataFrame
#
# Loops are fundamental methods that repeat a block of code multiple times. There are mainly two types of loops in Python, the ```for``` lop and the ``` while ``` loop.
#
# 1. ```for``` loop: Used to iterate over a sequence (like a list, tuple, string, or range) or other iterable objects.
#
# 2. ```while``` loop: Used to repeat a block of code as long as a condition is True.

# %%
# Let's identify all questions that contain the keyword "boss", which might indicate
# that the question is related to career development.

# To avoid repeatitive processing of the same question, we first identify all the unique questions in the dataset.
unique_questions = QA[['QID', 'Question_English']].drop_duplicates()
career_questions = []
for i in range(unique_questions.shape[0]):
    if 'boss' in unique_questions['Question_English'].iloc[i].lower():
        career_questions.append(unique_questions[['QID', 'Question_English']].iloc[i])
print(len(career_questions))
# Out:
# 344

# %% [markdown]
# * As we introduced earlier, ```.lower()``` is a method that operates on strings (text data). Its purpose is to convert any uppercase letters within the string to their lowercase equivalents.

# %%
# We can identify the same set of questions using a while loop.
# Out:
# 344

# %% [markdown]
# * ```qcount = 0``` A counter variable qcount is initialized to 0. This variable will keep track of the current question being examined.

# %% [markdown]
# #### Select rows from ```pandas.DataFrame``` based on conditions

# %%
# Select a subset of the QA dataset where the answer is longer than 3000 English
# characters.
# Here we only have one single condition enforced.
# Out:
#              QID                                   Question_English  \
# 2      100788013  I have been suffering from insomnia for half a...
# 3      100788013  I have been suffering from insomnia for half a...
# 4      100788013  I have been suffering from insomnia for half a...
# 6      100788013  I have been suffering from insomnia for half a...
# 7      100788013  I have been suffering from insomnia for half a...
# ...          ...                                                ...
# 86368  100794048  I often tend to overcomplicate things. Why do ...
# 86374  100794141  We have all experienced marriage, after gettin...
# 86377  100794052  I feel very insecure and do not want to intera...
# 86386  100794213  Too concerned about others' opinions and feeli...
# 86393  100794330  Always unable to stop recalling the past, to t...
#
#         author_ID                                     Answer_English  \
# 2      1000598896  Hello! ? I saw the issue you raised about inso...
# 3      1000598896  Hello! ? I saw the issue you raised about inso...
# 4      1006273111  Hi, I just want to hug you. I can feel the kin...
# 6      1007632006  Hello! I?ve been suffering from insomnia for h...
# 7      1007632006  Hello! I?ve been suffering from insomnia for h...
# ...           ...                                                ...
# 86368  1008285647  Hey there! I totally understand your feelings ...
# 86374  1008660160  Hello, title owner, I can feel your love and a...
# 86377  1007631758  Dear girl, hello?? I'm Susu, sending you a big...
# 86386  1005261485  OP, hello, I hope my reply can give you some h...
# 86393  1005261485  Hello, I hope my response can bring you some h...
#
#        Usefulness_vote  Comment_count  Received_Bonus_Yes_No New_Column
# 2                    8              2                      1        Yes
# 3                    8              2                      0         No
# 4                    6              0                      0         No
# 6                    5              0                      1        Yes
# 7                    5              0                      0         No
# ...                ...            ...                    ...        ...
# 86368                5              0                      1        Yes
# 86374                6              1                      1        Yes
# 86377                5              0                      1        Yes
# 86386                5              0                      0         No
# 86393                7              0                      0         No
#
# [18611 rows x 8 columns]

# %%
# Select a subset of the QA dataset where the answer is longer than 3000 English
# characters but shorter than 5000 English characters.
# Two conditions take effect.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ddeeab21a2d0> in <cell line: 0>()
#       2 # characters but shorter than 5000 English characters.
#       3 # Two conditions take effect.
# ----> 4 QA[(QA['Answer_English'].str.len() > 3000) & (QA[QA['Answer_English'].str.len() < 5000])]
#
# NameError: name 'QA' is not defined

# %%
# Select a subset of the QA dataset where the answer either received a bonus or a comment.
# Out:
#              QID                                   Question_English  \
# 2      100788013  I have been suffering from insomnia for half a...
# 3      100788013  I have been suffering from insomnia for half a...
# 9      100788013  I have been suffering from insomnia for half a...
# 10     100788013  I have been suffering from insomnia for half a...
# 14     100788017  I can't describe what exactly is "odd" about m...
# ...          ...                                                ...
# 86364  100794048  I often tend to overcomplicate things. Why do ...
# 86374  100794141  We have all experienced marriage, after gettin...
# 86375  100794141  We have all experienced marriage, after gettin...
# 86376  100794141  We have all experienced marriage, after gettin...
# 86384  100794226  Does reaching the level of Gu Yan mean that th...
#
#         author_ID                                     Answer_English  \
# 2      1000598896  Hello! ? I saw the issue you raised about inso...
# 3      1000598896  Hello! ? I saw the issue you raised about inso...
# 9      1005359282  Hello. I feel that insomnia is still quite com...
# 10     1009083171  Hello,\nWhat do you think is the reason for yo...
# 14     1007961499  Hello, host. I understand that you want to do ...
# ...           ...                                                ...
# 86364  1005493626  Hello, I'm Yi Ya Shu, and I am willing to acco...
# 86374  1008660160  Hello, title owner, I can feel your love and a...
# 86375     6746445  Hello, it seems that there is a lot of informa...
# 86376  1000648295  Hello! Two people in love may not necessarily ...
# 86384  1006901330  Good evening. Recently, Gu Ai Ling has been al...
#
#        Usefulness_vote  Comment_count  Received_Bonus_Yes_No New_Column
# 2                    8              2                      1        Yes
# 3                    8              2                      0         No
# 9                    2              1                      0         No
# 10                   0              1                      0         No
# 14                   3              1                      0         No
# ...                ...            ...                    ...        ...
# 86364               15              1                      1        Yes
# 86374                6              1                      1        Yes
# 86375                3              1                      0         No
# 86376                2              1                      0         No
# 86384               10              2                      1        Yes
#
# [9129 rows x 8 columns]

# %% [markdown]
# #### Calculate row and column means and correlations

# %%
# Calculate the mean of Received_Bonus_Yes_No, Usefulness_vote, Comment_count
# Out:
# Received_Bonus_Yes_No    0.226779
# Usefulness_vote          3.696066
# Comment_count            0.188108
# dtype: float64

# %%
# Can we calculate means of these columns using a lambda function
# Out:
# Received_Bonus_Yes_No    0.226779
# Usefulness_vote          3.696066
# Comment_count            0.188108
# dtype: float64

# %% [markdown]
# * When you apply a ```lambda``` function to a pandas ```Series``` using the ```apply()``` method, the function is applied to each element in the Series.
#
# * By default, when you apply a ```lambda``` function to a pandas ```DataFrame``` using the ```apply()``` method, the function is applied to each column of the DataFrame.

# %%
# For the three columns, calculate the mean of each row.
# Out:
# 0        0.666667
# 1        0.666667
# 2        3.666667
# 3        3.333333
# 4        2.000000
#            ...
# 86392    1.666667
# 86393    2.333333
# 86394    1.000000
# 86395    0.666667
# 86396    0.666667
# Length: 86397, dtype: float64

# %%
# Calculate the correlation coefficient between two numeric columns.
qa_corr = QA[['Received_Bonus_Yes_No', 'Usefulness_vote', 'Comment_count']].corr()
print(qa_corr)
# Out:
#                        Received_Bonus_Yes_No  Usefulness_vote  Comment_count
# Received_Bonus_Yes_No               1.000000         0.532264       0.058185
# Usefulness_vote                     0.532264         1.000000       0.191210
# Comment_count                       0.058185         0.191210       1.000000

# %% [markdown]
# #### Handling duplicate and missing values

# %%
# How to check if there are any duplicate rows in the dataset?
duplicates = QA.duplicated()
print(duplicates)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 86392    False
# 86393    False
# 86394    False
# 86395    False
# 86396    False
# Length: 86397, dtype: bool

# %% [markdown]
# * ```.duplicated()``` checks each row of the DataFrame and identifies whether it is a duplicate of a previous row.

# %%
print(QA[duplicates])
# There seems to be no duplicate rows in the dataset
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, QID, Question_English, author_ID, Answer_English, Usefulness_vote, Comment_count, Received_Bonus_Yes_No]
# Index: []

# %%
# In case there are duplicate rows, the function drop_duplicates can identifies
# and removes rows that have identical values in all or a subset of columns.
QA.drop_duplicates()
# Out:
#        Unnamed: 0        QID  \
# 0               0  100788023
# 1               1  100788009
# 2               2  100788013
# 3               3  100788013
# 4               4  100788013
# ...           ...        ...
# 86392       86392  100794310
# 86393       86393  100794330
# 86394       86394  100794330
# 86395       86395  100794348
# 86396       86396  100794327
#
#                                         Question_English   author_ID  \
# 0      Watching the elderly matchmaking program was v...  1004398689
# 1      Falling in love with someone else and breaking...  1006712632
# 2      I have been suffering from insomnia for half a...  1000598896
# 3      I have been suffering from insomnia for half a...  1000598896
# 4      I have been suffering from insomnia for half a...  1006273111
# ...                                                  ...         ...
# 86392  A 22-year-old girl, no one is here to accompan...  1006887364
# 86393  Always unable to stop recalling the past, to t...  1005261485
# 86394  Always unable to stop recalling the past, to t...  1004962530
# 86395  What to do if I have feelings for my sister-in...  1000648295
# 86396  I have been diagnosed with severe depression a...  1006643830
#
#                                           Answer_English  Usefulness_vote  \
# 0      Hello. Let's start by talking about young peop...                2
# 1      Hello! Sending you a virtual hug first. Thumbs...                2
# 2      Hello! ? I saw the issue you raised about inso...                8
# 3      Hello! ? I saw the issue you raised about inso...                8
# 4      Hi, I just want to hug you. I can feel the kin...                6
# ...                                                  ...              ...
# 86392  Hello, OP. Throughout the entire post, I notic...                5
# 86393  Hello, I hope my response can bring you some h...                7
# 86394  Reading your question inadvertently reminded m...                3
# 86395  Hello, how do you understand two people becomi...                2
# 86396  Hello! I'm from the community of Whale Social ...                2
#
#        Comment_count  Received_Bonus_Yes_No
# 0                  0                      0
# 1                  0                      0
# 2                  2                      1
# 3                  2                      0
# 4                  0                      0
# ...              ...                    ...
# 86392              0                      0
# 86393              0                      0
# 86394              0                      0
# 86395              0                      0
# 86396              0                      0
#
# [86397 rows x 8 columns]

# %%
# Sometimes a dataset might contain missing values (NA). To check for missing values
missing_values = QA.isna()
print(missing_values)
# Out:
#        Unnamed: 0    QID  Question_English  author_ID  Answer_English  \
# 0           False  False             False      False           False
# 1           False  False             False      False           False
# 2           False  False             False      False           False
# 3           False  False             False      False           False
# 4           False  False             False      False           False
# ...           ...    ...               ...        ...             ...
# 86392       False  False             False      False           False
# 86393       False  False             False      False           False
# 86394       False  False             False      False           False
# 86395       False  False             False      False           False
# 86396       False  False             False      False           False
#
#        Usefulness_vote  Comment_count  Received_Bonus_Yes_No
# 0                False          False                  False
# 1                False          False                  False
# 2                False          False                  False
# 3                False          False                  False
# 4                False          False                  False
# ...                ...            ...                    ...
# 86392            False          False                  False
# 86393            False          False                  False
# 86394            False          False                  False
# 86395            False          False                  False
# 86396            False          False                  False
#
# [86397 rows x 8 columns]

# %%
# Check if any missing values exist in each column
missing_values_per_column = QA.isna().any(axis = 0)
print(missing_values_per_column)
# Out:
# Unnamed: 0               False
# QID                      False
# Question_English         False
# author_ID                False
# Answer_English           False
# Usefulness_vote          False
# Comment_count            False
# Received_Bonus_Yes_No    False
# dtype: bool

# %% [markdown]
# * ```QA.isna()``` This part applies the ```.isna()``` method to the DataFrame QA. The ```.isna()``` method checks each individual cell within the DataFrame. If a cell is empty or contains a missing value (often represented as NaN which stands for "Not a Number"), it's marked as True; otherwise, it's marked as False. The result is a new DataFrame with the same shape as QA, but with True/False values indicating missing data.
#
# * The ```.any()``` method is then chained to the result of ```QA.isna()```. The ```.any()``` method is applied column-wise (because of the default axis=0 behavior) to the True/False DataFrame. For each column, if there is at least one True value (meaning at least one missing value in that column), ```.any()``` will return True for that column. Otherwise, it returns False.

# %%
# Check if any missing values exist in each row
missing_values_per_row = QA.isna().any(axis=1)
print(missing_values_per_row)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 86392    False
# 86393    False
# 86394    False
# 86395    False
# 86396    False
# Length: 86397, dtype: bool

# %%
# Check for missing values and summarize
missing_values = QA.isna()
missing_values_per_column = missing_values.any()
total_missing_values = missing_values.sum().sum()

print("Missing values per column:\n", missing_values_per_column)
print("\nTotal missing values:", total_missing_values)
# Out:
# Missing values per column:
#  Unnamed: 0               False
# QID                      False
# Question_English         False
# author_ID                False
# Answer_English           False
# Usefulness_vote          False
# Comment_count            False
# Received_Bonus_Yes_No    False
# dtype: bool
#
# Total missing values: 0

# %% [markdown]
# * Missing values can be either deleted, or imputed (i.e., replaced with mean, median, or mode of the respective feature.)

# %%
# Drop any row that contains at least one missing value (NaN).
QA_dropped = QA.dropna()
print(QA_dropped.shape, QA.shape)
# Out:
# (86397, 8) (86397, 8)

# %% [markdown]
# * After dropping missing values, the dataset remains the same.

# %%
# Impute missing values in the QA dataset
QA['Usefulness_vote_imputed'] = QA['Usefulness_vote'].fillna(QA['Usefulness_vote'].mean())

# %% [markdown]
# #### Create New Columns using Existing Columns

# %% [markdown]
# * Scenario 1: Create a new column that calculate the total number of usefulness votes and count of comments an answer received. Name this column as "Patient Feedback".

# %%
QA['Patient Feedback'] = QA['Usefulness_vote'] + QA['Comment_count']
print(QA[['Usefulness_vote', 'Comment_count', 'Patient Feedback']])
# Out:
#        Usefulness_vote  Comment_count  Patient Feedback
# 0                    2              0                 2
# 1                    2              0                 2
# 2                    8              2                10
# 3                    8              2                10
# 4                    6              0                 6
# ...                ...            ...               ...
# 86392                5              0                 5
# 86393                7              0                 7
# 86394                3              0                 3
# 86395                2              0                 2
# 86396                2              0                 2
#
# [86397 rows x 3 columns]

# %% [markdown]
# * Scenario 2: Create a new column 'QuestionType' that indicates the type of question based on keywords in the 'Question_English' column. For instance, 'Career' if the question contains "job" or "career", 'Relationship' if it contains "relationship" or "family", and 'MentalHealth' otherwise.

# %%
QA['QuestionType'] = QA['Question_English'].apply(lambda x: 'Career' if any(keyword in x.lower() for keyword in ['job', 'career']) else 'Relationship' if any(keyword in x.lower() for keyword in ['relationship', 'family']) else 'MentalHealth')
print(QA[['QuestionType']])
# Out:
#        QuestionType
# 0      MentalHealth
# 1      Relationship
# 2      MentalHealth
# 3      MentalHealth
# 4      MentalHealth
# ...             ...
# 86392        Career
# 86393  MentalHealth
# 86394  MentalHealth
# 86395  MentalHealth
# 86396  MentalHealth
#
# [86397 rows x 1 columns]

# %% [markdown]
# * Scenario 3: Create a new column 'BonusAndUsefulness' that combines the information from 'Received_Bonus_Yes_No' and 'Usefulness_vote'. For example, 'Bonus_HighUsefulness' if the answer received a bonus and has a high usefulness vote, 'NoBonus_HighUsefulness' if it didn't receive a bonus but has a high usefulness vote, and so on.

# %%
QA['BonusAndUsefulness'] = QA.apply(lambda row: f"{row['Received_Bonus_Yes_No']}_{'HighUsefulness' if row['Usefulness_vote'] > 5 else 'LowUsefulness'}", axis=1)
print(QA['BonusAndUsefulness'])
# Out:
# 0         0_LowUsefulness
# 1         0_LowUsefulness
# 2        1_HighUsefulness
# 3        0_HighUsefulness
# 4        0_HighUsefulness
#                ...
# 86392     0_LowUsefulness
# 86393    0_HighUsefulness
# 86394     0_LowUsefulness
# 86395     0_LowUsefulness
# 86396     0_LowUsefulness
# Name: BonusAndUsefulness, Length: 86397, dtype: object

# %% [markdown]
# #### Matplotlib for visualization
# * plot: create line plots
# * scatter: create scatter plots
# * bar: create bar charts
# * hist: create histograms
# * legend: add legends to plots
# * xlabel, ylabel: set horizontal and vertical axis labels and titles
# * xlim, ylim: set horizontal and vertical axis range limits
# * xticks, yticks: customize tick positions and labels

# %% [markdown]
# * Scenario 1: Visualizing the Distribution of Answer Lengths

# %%
import matplotlib.pyplot as plt

plt.hist(QA['Answer_English'].str.len(), bins=50)
plt.xlabel('Answer Length (Characters)')
plt.ylabel('Frequency')
plt.title('Distribution of Answer Lengths')
plt.show()

# %% [markdown]
# * Scenario 2: Relationship between Usefulness Vote and Comment Count

# %%
plt.scatter(QA['Usefulness_vote'], QA['Comment_count'])
plt.xlabel('Usefulness Vote')
plt.ylabel('Comment Count')
plt.title('Relationship between Usefulness Vote and Comment Count')
plt.show()

# %% [markdown]
# * Scenario 3: Relationship between answer lengths and usefulness votes.

# %%
plt.scatter(QA['Answer_English'].str.len(), QA['Usefulness_vote'])
plt.xlabel('Answer Length')
plt.ylabel('Usefulness votes')
plt.title('Relationship between Usefulness Vote and Answer Length')
plt.show()

# %% [markdown]
# * Scenario 4: Do answers that received bonuses and answers that did not receive any bonus differ in average length?

# %%
# Calculate average answer length for answers with and without bonuses
bonus_avg_length = QA[QA['Received_Bonus_Yes_No'] == 1]['Answer_English'].str.len().mean()
no_bonus_avg_length = QA[QA['Received_Bonus_Yes_No'] == 0]['Answer_English'].str.len().mean()

# Create the bar chart
labels = ['Bonus', 'No Bonus']
lengths = [bonus_avg_length, no_bonus_avg_length]

plt.bar(labels, lengths)
plt.xlabel('Bonus Received')
plt.ylabel('Average Answer Length')
plt.title('Average Answer Length by Bonus Status')
plt.show()
